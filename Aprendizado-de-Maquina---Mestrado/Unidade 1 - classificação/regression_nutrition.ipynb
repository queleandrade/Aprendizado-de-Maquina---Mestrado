# %%
from google.colab import userdata
import os

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

data = pd.read_excel("/content/drive/MyDrive/datasets/nutrition.xlsx", index_col=None)

# %%
data = data.iloc[:,1:]
data
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
data.columns
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
# ...

# %%
data['calories']
# Out:
# 0       381
# 1       691
# 2        25
# 3       367
# 4       144
#        ...
# 8784    125
# 8785    206
# 8786    277
# 8787    121
# 8788    121
# Name: calories, Length: 8789, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X, y = data[['serving_size', 'total_fat', 'saturated_fat',
       'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
       'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
       'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
       'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
       'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
       'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
       'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
       'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
       'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
       'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
       'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
       'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
       'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
       'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
       'ash', 'caffeine', 'theobromine', 'water']], data['calories']

X = X.replace(' g','', regex=True)
X = X.replace('g','', regex=True)
X = X.replace('mg','', regex=True)
X = X.replace('m','', regex=True)
X = X.replace(' m','', regex=True)
X = X.replace('c','', regex=True)
X = X.replace(' IU','', regex=True)

# X = X.astype(float)
# y = y.astype(float)

X = np.asarray(X).astype('float32')

X = np.nan_to_num(X, nan=0)

# %%
X
# Out:
# array([[100.  ,   0.1 ,   0.  , ...,   0.  ,   0.  ,   8.32],
#        [100.  ,  72.  ,   6.2 , ...,   0.  ,   0.  ,   3.52],
#        [100.  ,   0.2 ,   0.  , ...,   0.  ,   0.  ,  92.3 ],
#        ...,
#        [100.  ,  23.  ,  12.  , ...,   0.  ,   0.  ,  59.8 ],
#        [100.  ,   3.  ,   1.1 , ...,   0.  ,   0.  ,  73.43],
#        [100.  ,   3.  ,   1.1 , ...,   0.  ,   0.  ,  73.43]],
#       dtype=float32)

# %%
y = y.astype('category').cat.codes
y = np.asarray(y).astype('int')
y
# Out:
# array([381, 635,  25, ..., 277, 121, 121])

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)

# x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.5)

print('Shape de x_train', x_train.shape)
#print('Shape de x_val', x_val.shape)
print('Shape de x_test', x_test.shape)

print('Shape de y_train', y_train.shape)
#print('Shape de y_val', y_val.shape)
print('Shape de y_test', y_test.shape)
# Out:
# Shape de x_train (7031, 74)
# Shape de x_test (1758, 74)
# Shape de y_train (7031,)
# Shape de y_test (1758,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.preprocessing import StandardScaler

y_scaler = StandardScaler()

y_train = y_scaler.fit_transform(y_train.reshape(-1,1))
y_test = y_scaler.transform(y_test.reshape(-1,1))

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

# %%
model = Sequential()

model.add(Dense(128, input_shape=(74,), activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='adam', metrics=['mae'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# %%
batch_size = 16
epochs = 500

history = model.fit(
    x_train, y_train,
    validation_split=0.2,
    epochs=500,
    callbacks=[early_stop]
)

# ,
#     callbacks=[early_stop]
# Out:
# Epoch 1/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2349 - mae: 0.3269 - val_loss: 0.0638 - val_mae: 0.1600
# Epoch 2/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1056 - mae: 0.2145 - val_loss: 0.0494 - val_mae: 0.1548
# Epoch 3/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0791 - mae: 0.1821 - val_loss: 0.0410 - val_mae: 0.1440
# Epoch 4/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0621 - mae: 0.1624 - val_loss: 0.0341 - val_mae: 0.1275
# Epoch 5/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0589 - mae: 0.1542 - val_loss: 0.0357 - val_mae: 0.1423
# Epoch 6/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0440 - mae: 0.1416 - val_loss: 0.0290 - val_mae: 0.1269
# Epoch 7/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0387 - mae: 0.1339 - val_loss: 0.0403 - val_mae: 0.1584
# Epoch 8/500
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0398 - mae: 0.1317 - val_loss: 0.0282 - val_mae: 0.1251
# Epoch 9/500
# ...

# %%
import matplotlib.pyplot as plt

# Plotando o historico do processo de treinamento
plt.figure(figsize=(20, 5))
plt.plot(history.history['loss'], color='blue')
plt.plot(history.history['val_loss'], color='red')
plt.title('Model loss', fontsize=20)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Treinamento', 'Validação'], loc='upper right', fontsize=14)
plt.show()


import matplotlib.pyplot as plt

# Plotando o historico do processo de treinamento
plt.figure(figsize=(20, 5))
plt.plot(history.history['mae'], color='blue')
plt.plot(history.history['val_mae'], color='red')
plt.title('Model loss', fontsize=20)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Treinamento', 'Validação'], loc='upper right', fontsize=14)
plt.show()

# %%
y_pred_scaled = model.predict(x_test)

y_pred = y_scaler.inverse_transform(y_pred_scaled)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred_scaled)

print("MSE:", mse)
# Out:
# MSE: 0.02433682247620128

# %%
plt.figure(figsize=(6,6))

plt.scatter(y_test, y_pred_scaled, label="Predictions")
plt.plot([min(y_test), max(y_test)],
         [min(y_test), max(y_test)],
         linewidth=2,
         label="Perfect prediction")

plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("True vs Predicted")
plt.legend()

plt.show()

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
modelo = LinearRegression()

modelo.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_scaled_linear = model.predict(x_test)

y_pred_linear = y_scaler.inverse_transform(y_pred_scaled_linear)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
loss = np.mean((y_test - y_pred_scaled_linear) ** 2)

print("MSE:", loss)
# Out:
# MSE: 0.02433682247620128

# %%
plt.figure(figsize=(6,6))

plt.scatter(y_test, y_pred_scaled_linear, label="Predictions")
plt.plot([min(y_test), max(y_test)],
         [min(y_test), max(y_test)],
         linewidth=2,
         label="Perfect prediction")

plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("True vs Predicted")
plt.legend()

plt.show()

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# modelo
model = xgb.XGBRegressor(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05
)

# treino
model.fit(x_train, y_train)

# %%
# predição
y_pred = model.predict(x_test)

# %%
y_pred_scaled_xgb = model.predict(x_test)

#y_pred_linear_xgb = y_scaler.inverse_transform(y_pred_scaled_xgb)

# %%
loss = np.mean((y_test - y_pred_scaled_xgb) ** 2)

print("MSE:", loss)

# %% [markdown]
# Exercícios:
#
# *   Tentar tratar o overfiting da MLP e utilizar Batch Normalization
# *   Pesquisar e usar o modelo Wide & Deep Model
# ex:
#
# ![image.png](data:image/png;base64,...)
#
#
# * Residual MLP (Inspirada na ResNet)
#
# ![image.png](data:image/png;base64,...)
